# %% [markdown]
# <a href="https://colab.research.google.com/github/luisadosch/Final-Project-snapAddy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Loading & Transforming

# %%
import json
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
DATA_DIR = Path("/content/sample_data")

annotated_path = DATA_DIR / "linkedin-cvs-annotated.json"
not_annotated_path = DATA_DIR / "linkedin-cvs-not-annotated.json"
department_path = DATA_DIR / "department-v2.csv"
seniority_path = DATA_DIR / "seniority-v2.csv"

# %%
with open(annotated_path, "r", encoding="utf-8") as f:
    cvs_annotated = json.load(f)

with open(not_annotated_path, "r", encoding="utf-8") as f:
    cvs_not_annotated = json.load(f)

department_df = pd.read_csv(department_path)
seniority_df = pd.read_csv(seniority_path)

# %% [markdown]
# ## 1.1 Label Datasets (department labels & seniority labels)

# %% [markdown]
# We load the department and seniority files into dataframes

# %%
department_df.info()
department_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10145 entries, 0 to 10144
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    10145 non-null  object
#  1   label   10145 non-null  object
# dtypes: object(2)
# memory usage: 158.6+ KB
# (10145, 2)

# %% [markdown]
# Department labels file has 10.145 rows and 2 columns

# %%
seniority_df.info()
seniority_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9428 entries, 0 to 9427
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    9428 non-null   object
#  1   label   9428 non-null   object
# dtypes: object(2)
# memory usage: 147.4+ KB
# (9428, 2)

# %% [markdown]
# Seniority labels file has 9.428 rows and 2 columns

# %%
department_df.nunique()
# Out:
# text     10145
# label       11
# dtype: int64

# %%
department_df['label'].value_counts()
# Out:
# label
# Marketing                 4295
# Sales                     3328
# Information Technology    1305
# Business Development       620
# Project Management         201
# Consulting                 167
# Administrative              83
# Other                       42
# Purchasing                  40
# Customer Support            33
# Human Resources             31
# Name: count, dtype: int64

# %% [markdown]
# There are 11 distinct department labels. Among them, Marketing is the most common and Human Resources the least

# %%
seniority_df['label'].value_counts()
# Out:
# label
# Senior        3733
# Lead          3546
# Director       984
# Management     756
# Junior         409
# Name: count, dtype: int64

# %% [markdown]
# There are 5 distinct seniority level labels. Among them, Senior is the most common and Junior the least

# %%
print("\nDepartment labels:")
display(department_df.head(10))

print("\nSeniority labels:")
display(seniority_df.head(10))
# Out:
# Department labels:
#                                                text               label
# 0                   Adjoint directeur communication           Marketing
# 1                     Advisor Strategy and Projects  Project Management
# 2                               Beratung & Projekte  Project Management
# 3                      Beratung & Projektmanagement  Project Management
# 4  Beratung und Projektmanagement kommunale Partner  Project Management
# 5                           Cadre marketing digital           Marketing
# 6                           Chargé de communication           Marketing
# 7                  Chargé de communication digitale           Marketing
# 8              Chargé de communication et marketing           Marketing
# 9                    Chargé de Webmarketing SEO/SEA           Marketing
# Seniority labels:
#                                         text   label
# 0                                    Analyst  Junior
# 1                         Analyste financier  Junior
# 2          Anwendungstechnischer Mitarbeiter  Junior
# 3                       Application Engineer  Senior
# 4                      Applications Engineer  Senior
# 5  Architecte SI - Chef de projet Applicatif    Lead
# 6                                  Associate  Junior
# 7                       Associate - Research  Junior
# 8                          Associate Partner  Junior
# 9                        Associate Recruiter  Junior

# %% [markdown]
# We can already see that, the job titles are of different word lengths, in upper and lowercase, in different languages and can contain spacing characters such as *&* or *-* or */*

# %% [markdown]
# ## 1.2 CV Datasets (annotated & not annotated)

# %%
type(cvs_annotated)
# Out:
# list

# %%
type(cvs_not_annotated)
# Out:
# list

# %% [markdown]
# Both files are of type list

# %%
type(cvs_annotated[0])
# Out:
# list

# %%
print(cvs_annotated[0])
# Out:
# [{'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'Prokurist', 'startDate': '2019-08', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Management'}, {'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'CFO', 'startDate': '2019-07', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Management'}, {'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'Betriebswirtin', 'startDate': '2019-07', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Professional'}, {'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'Prokuristin', 'startDate': '2019-07', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Management'}, {'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'CFO', 'startDate': '2019-07', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Management'}, {'organization': 'Nagel Car Group', 'linkedin': '', 'position': 'Buchhalterin', 'startDate': '2000-05', 'endDate': '2019-06', 'status': 'INACTIVE', 'department': 'Other', 'seniority': 'Professional'}]

# %%
type(cvs_not_annotated[0])
# Out:
# list

# %%
print(cvs_not_annotated[0])
# Out:
# [{'organization': 'Keeping The Books, Bookkeeping', 'linkedin': '', 'position': 'Bookkeeper', 'startDate': '2023-03', 'endDate': None, 'status': 'ACTIVE'}, {'organization': 'Playful Paws', 'linkedin': '', 'position': 'Co-Owner', 'startDate': '2018-11', 'endDate': None, 'status': 'ACTIVE'}, {'organization': 'S&R services', 'linkedin': '', 'position': 'Logistics Officer', 'startDate': '2019-09', 'endDate': '2024-04', 'status': 'INACTIVE'}, {'organization': 'ABC Supply Co. Inc.', 'linkedin': 'https://www.linkedin.com/company/abc-supply', 'position': 'Truck driver/ laborer', 'startDate': '2019-03', 'endDate': '2019-09', 'status': 'INACTIVE'}, {'organization': 'MB Railways', 'linkedin': '', 'position': 'Fuel Driver', 'startDate': '2018-03', 'endDate': '2019-03', 'status': 'INACTIVE'}, {'organization': 'Sysco', 'linkedin': 'https://www.linkedin.com/company/sysco', 'position': 'Food Delivery Driver', 'startDate': '2017-10', 'endDate': '2018-02', 'status': 'INACTIVE'}, {'organization': 'UPS Freight', 'linkedin': 'https://www.linkedin.com/company/ups-freight', 'position': 'Regional driver', 'startDate': '2016-10', 'endDate': '2017-03', 'status': 'INACTIVE'}, {'organization': "Domino's Pizza", 'linkedin': '', 'position': 'delivery/sales/MIT', 'startDate': '2012-04', 'endDate': '2012-06', 'status': 'INACTIVE'}]

# %% [markdown]
# Looking at the first element of both files shows us that elements are of type list -> files have a nested structure

# %%
type(cvs_annotated[0][0])
# Out:
# dict

# %%
print(cvs_annotated[0][0])
# Out:
# {'organization': 'Depot4Design GmbH', 'linkedin': 'https://www.linkedin.com/company/depot4design-gmbh', 'position': 'Prokurist', 'startDate': '2019-08', 'endDate': None, 'status': 'ACTIVE', 'department': 'Other', 'seniority': 'Management'}

# %%
type(cvs_not_annotated[0][0])
# Out:
# dict

# %%
print(cvs_not_annotated[0][0])
# Out:
# {'organization': 'Keeping The Books, Bookkeeping', 'linkedin': '', 'position': 'Bookkeeper', 'startDate': '2023-03', 'endDate': None, 'status': 'ACTIVE'}

# %% [markdown]
# The inner list of both files contains dictionaries

# %%
unique_types_level_1 = {type(cv) for cv in cvs_annotated}
unique_types_level_2 = {type(job) for cv in cvs_annotated for job in cv}
unique_types_level_3 = {
    type(v)
    for cv in cvs_annotated
    for job in cv
    for v in job.values()
}

unique_types_level_1, unique_types_level_2, unique_types_level_3
# Out:
# ({list}, {dict}, {NoneType, str})

# %%
unique_types_level_1_not = {type(cv) for cv in cvs_not_annotated}
unique_types_level_2_not = {type(job) for cv in cvs_not_annotated for job in cv}
unique_types_level_3_not = {
    type(v)
    for cv in cvs_not_annotated
    for job in cv
    for v in job.values()
}

unique_types_level_1_not, unique_types_level_2_not, unique_types_level_3_not
# Out:
# ({list}, {dict}, {NoneType, str})

# %% [markdown]
# The inspection reveals a three level hierarchical structure. The dataset is a list of CVs, each CV is a list of job entries, and each job entry is a dictionary whith values. Since no job field contains nested lists or dictionaries, the hierarchy ends at the job level

# %%
print("Number of annotated CVs:", len(cvs_annotated))
print("Number of non-annotated CVs:", len(cvs_not_annotated))
# Out:
# Number of annotated CVs: 609
# Number of non-annotated CVs: 390

# %%
print("\nType of one CV object (annotated):", type(cvs_annotated[0]))
print("\nType of one CV object (not annotated):", type(cvs_not_annotated[0]))
# Out:
# Type of one CV object (annotated): <class 'list'>
#
# Type of one CV object (not annotated): <class 'list'>

# %% [markdown]
# We have 609 CVs with labels and 390 CVs without labels. Both files are a list of lists, where one CV = list

# %%
sum(len(cv) for cv in cvs_annotated)
# Out:
# 2638

# %%
sum(len(cv) for cv in cvs_not_annotated)
# Out:
# 1886

# %% [markdown]
# There are 2.637 job titles in the annotated data and 1.886 job titles in the not annotated data

# %% [markdown]
# ### 1.2.1 Turning the hierarchical CV data into a job-level DataFrame
#
# Because ML models require tabular inputs, we need to transform our hierarchical CV data into a job-level table, where each row represents one job entry

# %%
# Collect all unique key sets from annotated jobs
annotated_job_key_sets = {
    tuple(sorted(job.keys()))
    for cv in cvs_annotated
    for job in cv
}

len(annotated_job_key_sets), annotated_job_key_sets
# Out:
# (1,
#  {('department',
#    'endDate',
#    'linkedin',
#    'organization',
#    'position',
#    'seniority',
#    'startDate',
#    'status')})

# %%
not_annotated_job_key_sets = {
    tuple(sorted(job.keys()))
    for cv in cvs_not_annotated
    for job in cv
}

len(not_annotated_job_key_sets), not_annotated_job_key_sets
# Out:
# (1,
#  {('endDate', 'linkedin', 'organization', 'position', 'startDate', 'status')})

# %% [markdown]
# For that we create the following dataframe schema where each column corresponds to a field (key) from the job dictionary:
#
# - **organization** : name of the employer for a given job
# - **position** : job title text
# - **startDate** : start date of the job
# - **endDate** : end date of the job
# - **status** : indicates the status of a job
# - **department (annotated dataset only)** : department label for a job
# - **seniority (annotated dataset only)** : seniority level for a job

# %%
unique_linkedin_values = {
    job.get("linkedin")
    for cv in cvs_annotated
    for job in cv
}

list(unique_linkedin_values)[:10]
# Out:
# ['',
#  'https://www.linkedin.com/company/trane',
#  'https://www.linkedin.com/company/tremco-illbruck',
#  'https://www.linkedin.com/company/texasforestservice',
#  'https://www.linkedin.com/company/succesvol-tot-en-met-pensioen',
#  'https://www.linkedin.com/company/gehealthcare',
#  "https://www.linkedin.com/company/restaurant-l'archipel",
#  'https://www.linkedin.com/company/beckmann-verlag',
#  'https://www.linkedin.com/company/advokatfirmaet-schjodt',
#  'https://www.linkedin.com/company/western-digital']

# %% [markdown]
# We remove the linkedin field, because it only contains a URL to a linkedin page. We remove it because this does not contribute meaningful predictive signal for our project and would introduce noise and leakage risk into our pipeline

# %% [markdown]
# Because we want to perserve the hierarchy information (CV identity and job order), we explicitly add these columns to our dataframe schema:
#
# - **cv_id** : this links each job back to a CV (unique identifier for each CV)
# - **job_index** : this preserves the job order within a CV (position of a job within a CVs job list)
#
# This is necessary because job entries are not independent observations: they belong to the same individual and form a temporal sequence

# %% [markdown]
# #### 1.2.1.1 Job-level DataFrame for annotated CVs
#
# The variables *cv_id* and *job_index* are derived from the positional indices of CVs and jobs within the nested list structure using enumerate.
#
# All remaining columns are obtained by directly reading the corresponding fields from each job dictionary using key access

# %%
annotated_rows = []

for cv_id, cv in enumerate(cvs_annotated):
    for job_index, job in enumerate(cv):
        annotated_rows.append({
            "cv_id": cv_id,
            "job_index": job_index,
            "organization": job.get("organization"),
            "position": job.get("position"),
            "startDate": job.get("startDate"),
            "endDate": job.get("endDate"),
            "status": job.get("status"),
            "department": job.get("department"),
            "seniority": job.get("seniority"),
        })

jobs_annotated_df = pd.DataFrame(annotated_rows)

# %%
jobs_annotated_df.head(10)
# Out:
#    cv_id  job_index                         organization  \
# 0      0          0                    Depot4Design GmbH
# 1      0          1                    Depot4Design GmbH
# 2      0          2                    Depot4Design GmbH
# 3      0          3                    Depot4Design GmbH
# 4      0          4                    Depot4Design GmbH
# 5      0          5                      Nagel Car Group
# 6      1          0                   Computer Solutions
# 7      1          1                   Computer Solutions
# 8      1          2  Texas A&M University-Corpus Christi
# 9      1          3  Texas A&M University-Corpus Christi
#
#                           position startDate  endDate    status  \
# 0                        Prokurist   2019-08     None    ACTIVE
# 1                              CFO   2019-07     None    ACTIVE
# 2                   Betriebswirtin   2019-07     None    ACTIVE
# 3                      Prokuristin   2019-07     None    ACTIVE
# 4                              CFO   2019-07     None    ACTIVE
# 5                     Buchhalterin   2000-05  2019-06  INACTIVE
# 6              Solutions Architect   2024-03     None    ACTIVE
# 7          Senior Network Engineer   2019-07  2024-03  INACTIVE
# 8      Manager of Network Services   2017-02  2019-07  INACTIVE
# 9  Infrastructure Administrator II   2015-06  2017-02  INACTIVE
#
#                department     seniority
# 0                   Other    Management
# 1                   Other    Management
# 2                   Other  Professional
# 3                   Other    Management
# 4                   Other    Management
# 5                   Other  Professional
# 6  Information Technology  Professional
# 7  Information Technology        Senior
# 8  Information Technology  Professional
# 9  Information Technology  Professional

# %% [markdown]
# Results show that job entries within each CV are ordered in reverse chronological order, with job_index = 0 corresponding to the most recent position and increasing indices representing older roles (this is important to remember for later)

# %% [markdown]
# #### 1.2.1.2 Job-level DataFrame for non-annotated CVs
#
# We set department and seniority as None here

# %%
not_annotated_rows = []

for cv_id, cv in enumerate(cvs_not_annotated):
    for job_index, job in enumerate(cv):
        not_annotated_rows.append({
            "cv_id": cv_id,
            "job_index": job_index,
            "organization": job.get("organization"),
            "position": job.get("position"),
            "startDate": job.get("startDate"),
            "endDate": job.get("endDate"),
            "status": job.get("status"),
            "department": None,
            "seniority": None,
        })

jobs_not_annotated_df = pd.DataFrame(not_annotated_rows)

# %%
jobs_not_annotated_df.head(10)
# Out:
#    cv_id  job_index                    organization  \
# 0      0          0  Keeping The Books, Bookkeeping
# 1      0          1                    Playful Paws
# 2      0          2                    S&R services
# 3      0          3             ABC Supply Co. Inc.
# 4      0          4                     MB Railways
# 5      0          5                           Sysco
# 6      0          6                     UPS Freight
# 7      0          7                  Domino's Pizza
# 8      1          0        Erste Bank und Sparkasse
# 9      1          1                      DO & CO AG
#
#                                  position startDate  endDate    status  \
# 0                              Bookkeeper   2023-03     None    ACTIVE
# 1                                Co-Owner   2018-11     None    ACTIVE
# 2                       Logistics Officer   2019-09  2024-04  INACTIVE
# 3                   Truck driver/ laborer   2019-03  2019-09  INACTIVE
# 4                             Fuel Driver   2018-03  2019-03  INACTIVE
# 5                    Food Delivery Driver   2017-10  2018-02  INACTIVE
# 6                         Regional driver   2016-10  2017-03  INACTIVE
# 7                      delivery/sales/MIT   2012-04  2012-06  INACTIVE
# 8                  Strategy & Investments   2025-03     None    ACTIVE
# 9  International Event Operations Manager   2022-11  2024-05  INACTIVE
#
#   department seniority
# 0       None      None
# 1       None      None
# 2       None      None
# 3       None      None
# 4       None      None
# 5       None      None
# 6       None      None
# 7       None      None
# 8       None      None
# 9       None      None

# %% [markdown]
# ## 1.3 Missing values
#
# Before we inspect, it is important to note that some missing values are expected in our data.
#
# in **jobs_annotated_df**:
# - **endDate** = None → expected for active jobs (where status == "ACTIVE")
#
#
# in **jobs_not_annotated_df**:
# - **endDate** = None → expected for active jobs (where status == "ACTIVE")
# - **department** = None → expected in the non annotated data
# - **seniority** = None → expected in the non annotated data

# %%
jobs_annotated_df.isna().sum()
# Out:
# cv_id             0
# job_index         0
# organization      0
# position          0
# startDate       118
# endDate         741
# status            0
# department        0
# seniority         0
# dtype: int64

# %% [markdown]
# Most columns do not have missing values, except for startDate and endDate

# %% [markdown]
# As explained before, the missing values in endDate are expected if status is active. Therefore we want to see if these missing values actually correspond to an active status

# %%
enddate_missing_by_status = (
    jobs_annotated_df
    .assign(endDate_missing=jobs_annotated_df["endDate"].isna())
    .groupby("status")["endDate_missing"]
    .value_counts()
)

enddate_missing_by_status
# Out:
# status    endDate_missing
# ACTIVE    True                623
# INACTIVE  False              1897
# UNKNOWN   True                118
# Name: count, dtype: int64

# %% [markdown]
# - there are 623 active jobs whose endDate is missing
# - there are 1897 inactive jobs whose endDate is not missing
# - there are 118 jobs with unknown status whose endDate is missing
#
# This shows that all missing end dates occur for jobs with status active or unkown, while all inactive jobs have an end date.

# %% [markdown]
# So there is no issue with the missing end dates for active jobs and we can leave them as of now, but there are still 118 missing end dates for unknown status jobs.
# We noticed that the missing values in the unkown status might correspond to the missing values of startDate, since both are exactly 118.
# Therefore we inspect further:

# %%
# Number of jobs with UNKNOWN status and missing startDate
unknown_and_missing_start = jobs_annotated_df[
    (jobs_annotated_df["status"] == "UNKNOWN") &
    (jobs_annotated_df["startDate"].isna())
].shape[0]

# Number of jobs with UNKNOWN status
unknown_total = jobs_annotated_df[jobs_annotated_df["status"] == "UNKNOWN"].shape[0]

unknown_and_missing_end = jobs_annotated_df[
    (jobs_annotated_df["status"] == "UNKNOWN") &
    (jobs_annotated_df["endDate"].isna())
].shape[0]

unknown_and_missing_start, unknown_total, unknown_and_missing_end
# Out:
# (118, 118, 118)

# %% [markdown]
# Results show that all jobs marked with status unkown lack both a start date and an end date. Conversely, no jobs with missing start dates are observed outside this group. This indicates that incomplete temporal metadata is consistently captured via the unknown status rather than occurring randomly. This indicates that incomplete temporal metadata is consistently reflected in the job status and does not represent random missingness.

# %% [markdown]
# Same inspection for the not annotated dataset:

# %%
# Absolute number of missing values per column
jobs_not_annotated_df.isna().sum()
# Out:
# cv_id              0
# job_index          0
# organization       0
# position           0
# startDate         58
# endDate          477
# status             0
# department      1886
# seniority       1886
# dtype: int64

# %% [markdown]
# Most columns do not have missing values here aswell, except for startDate and endDate & as expected and previously explained department and seniority

# %%
na_enddate_missing_by_status = (
    jobs_not_annotated_df
    .assign(endDate_missing=jobs_not_annotated_df["endDate"].isna())
    .groupby("status")["endDate_missing"]
    .value_counts()
)

na_enddate_missing_by_status
# Out:
# status    endDate_missing
# ACTIVE    True                419
# INACTIVE  False              1409
# UNKNOWN   True                 58
# Name: count, dtype: int64

# %% [markdown]
# - there are 419 active jobs whose endDate is missing
# - there are 1409 inactive jobs whose endDate is not missing
# - there are 58 jobs with unknown status whose endDate is missing
#
# This shows that all missing end dates occur for jobs with status ACTIVE or UNKNOWN, while all INACTIVE jobs have an end date. This confirms that missing endDate values are expected by design and do not indicate any data quality issues.

# %% [markdown]
# From the other dataset, we can already suspect the same missingness in the unknown status, but we will inspect it for this dataset again:

# %%
# Number of jobs with UNKNOWN status and missing startDate
na_unknown_and_missing_start = jobs_not_annotated_df[
    (jobs_not_annotated_df["status"] == "UNKNOWN") &
    (jobs_not_annotated_df["startDate"].isna())
].shape[0]

# Number of jobs with UNKNOWN status
na_unknown_total = jobs_not_annotated_df[jobs_not_annotated_df["status"] == "UNKNOWN"].shape[0]

na_unknown_and_missing_end = jobs_not_annotated_df[
    (jobs_not_annotated_df["status"] == "UNKNOWN") &
    (jobs_not_annotated_df["endDate"].isna())
].shape[0]

na_unknown_and_missing_start, na_unknown_total, na_unknown_and_missing_end
# Out:
# (58, 58, 58)

# %% [markdown]
# Results show again that all jobs marked with status unkown lack both a start date and an end date. Conversely, no jobs with missing start dates are observed outside this group. This indicates that incomplete temporal metadata is consistently captured via the unknown status rather than occurring randomly. This indicates that incomplete temporal metadata is consistently reflected in the job status and does not represent random missingness.

# %% [markdown]
# We also look at the seniority and department datasets:

# %%
seniority_df.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# No missing values

# %%
department_df.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
# The missingness in the data was expected, missing end dates correspond to ongoing (active) positions and therefore represent meaningful missingness rather than data quality issues. Jobs with unknown status lack temporal information (both start and end dates) and are retained in the canonical dataset but will be excluded from predictions.

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# After validating data structure and quality, exploratory data analysis is conducted to inform subsequent modeling decisions. Dataset construction for baseline and extended models is therefore deferred until the exploratory findings are complete.

# %%
eda_df = jobs_annotated_df.copy()

print("Total annotated jobs:", len(eda_df))
# Out:
# Total annotated jobs: 2638

# %% [markdown]
# 2.638 annotated jobs

# %%
eda_df.head()
# Out:
#    cv_id  job_index       organization        position startDate endDate  \
# 0      0          0  Depot4Design GmbH       Prokurist   2019-08    None
# 1      0          1  Depot4Design GmbH             CFO   2019-07    None
# 2      0          2  Depot4Design GmbH  Betriebswirtin   2019-07    None
# 3      0          3  Depot4Design GmbH     Prokuristin   2019-07    None
# 4      0          4  Depot4Design GmbH             CFO   2019-07    None
#
#    status department     seniority
# 0  ACTIVE      Other    Management
# 1  ACTIVE      Other    Management
# 2  ACTIVE      Other  Professional
# 3  ACTIVE      Other    Management
# 4  ACTIVE      Other    Management

# %% [markdown]
# ## 2.1 Department distribution
#
# For our first step we will take a look at the distribution of the department label and understand how balanced or imbalanced the department labels are distributed.
#
# This is especially important since department is one of our target variable and its distribution helps us understand the difficulty of the prediction task.

# %%
dept_counts = eda_df["department"].value_counts()
dept_counts
# Out:
# department
# Other                     1252
# Information Technology     312
# Sales                      219
# Consulting                 195
# Project Management         175
# Marketing                  133
# Administrative              84
# Business Development        78
# Purchasing                  72
# Human Resources             70
# Customer Support            48
# Name: count, dtype: int64

# %%
dept_percent = dept_counts / dept_counts.sum() * 100
dept_percent.round(2)
# Out:
# department
# Other                     47.46
# Information Technology    11.83
# Sales                      8.30
# Consulting                 7.39
# Project Management         6.63
# Marketing                  5.04
# Administrative             3.18
# Business Development       2.96
# Purchasing                 2.73
# Human Resources            2.65
# Customer Support           1.82
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 5))
dept_counts.plot(kind="bar", color="DarkCyan")
plt.title("Department Distribution (Annotated Jobs)")
plt.ylabel("Number of Jobs")
plt.xlabel("Department Label")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# The department labels are highly imbalanced. Nearly half of all job entries (≈47%) are labeled as *Other*, while several departments such as *Customer Support*, *Human Resources*, and *Purchasing* account for less than 3% each.
#
# *Other* being almost half the dataset implies that many job titles are not mapped cleanly to predefined departments, keyword lists can therefore over-predict *Other*.
# Furthermore, rare classes such as *Customer Support* lack sufficient keyword coverage compared to others such as *Information Technology* whereby accuracy can vary strongly by class.
#
# This imbalance indicates that department prediction will be a challenging task, particularly for the rule-based approach and motivates the use of context aware models.

# %%
title_department_counts = (
    eda_df
    .groupby("position")["department"]
    .nunique()
    .sort_values(ascending=False)
)

# %%
title_department_counts.value_counts().sort_index()
# Out:
# department
# 1    2065
# 2       1
# Name: count, dtype: int64

# %%
multi_department_titles = title_department_counts[title_department_counts > 1]
titlemulti = multi_department_titles.index[0]

eda_df[eda_df["position"] == titlemulti][["position", "department"]].drop_duplicates()
# Out:
#                    position      department
# 32    Kaufmännischer Leiter           Sales
# 1335  Kaufmännischer Leiter  Administrative

# %% [markdown]
# - 2.065 job titles appear in exactly 1 department
# - only 1 job title (Kaufmännischer Leiter) appears in 2 departments (Sales and Administrative)
# - no job title appears in more than two departments
#
# This tells us that job titles are not ambiguous across departments, but each job is linked to exactly one department (except for one exception)

# %% [markdown]
# The department distribution reveals an imbalance, with nearly half of all jobs labeled as *Other*, and several departments being underrepresented. This indicates that department prediction based solely on the current job title is challenging, particularly for rule-based approaches that rely on keyword matching. The observed ambiguity motivates the incorporation of additional career information, such as previous job titles, under the assumption that individuals are unlikely to change departments frequently across their career. This can help smooth noisy predictions and help when the current title is vague

# %% [markdown]
# ## 2.2 Seniority distribution
#
# Next we will take a look at the distribution of the seniority levels and understand how balanced or imbalanced the seniority levels are distributed.
#
# This is especially important since seniority is another one of our target variables and its distribution helps us understand the difficulty of the prediction task.

# %%
sen_counts = eda_df["seniority"].value_counts()
sen_counts
# Out:
# seniority
# Professional    1219
# Lead             460
# Management       418
# Junior           230
# Senior           170
# Director         141
# Name: count, dtype: int64

# %%
sen_percent = sen_counts / sen_counts.sum() * 100
sen_percent.round(2)
# Out:
# seniority
# Professional    46.21
# Lead            17.44
# Management      15.85
# Junior           8.72
# Senior           6.44
# Director         5.34
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))
sen_counts.plot(kind="bar")
plt.title("Seniority Distribution (Annotated Jobs)")
plt.ylabel("Number of Jobs")
plt.xlabel("Seniority Level")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Seniority distribution also shows an imbalance, but less extreme than department:
# - One dominant class: Professional (~46%)
# - Distribution is skewed toward mid-career roles (Professional, Lead, Management), very early (Junior) and very late (Director) roles are rarer
# - No class is vanishingly small (all >5%)

# %%
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Left subplot: Department percentages
sns.barplot(
    x=dept_percent.values,
    y=dept_percent.index,
    color='DarkCyan',
    ax=axes[0]
)
axes[0].set_title("Department Distribution (%)")
axes[0].set_xlabel("Percentage")
axes[0].set_ylabel("Department")

# Right subplot: Seniority percentages
sns.barplot(
    x=sen_percent.values,
    y=sen_percent.index,
    ax=axes[1]
)
axes[1].set_title("Seniority Distribution (%)")
axes[1].set_xlabel("Percentage")
axes[1].set_ylabel("Seniority")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.3 Job Status Distribution
#
#
# We now take a look at the status distribution. This is very important as our prediciton will be based on the characteristics of the current job, meaning where the status is active.
# We need to understand how many active jobs there are in the data and whether CVs have multiple active jobs. This will also help us understand if an extension of the previous jobs would be promising.

# %%
status_counts = eda_df["status"].value_counts()
status_percent = status_counts / status_counts.sum() * 100

# %%
status_counts
# Out:
# status
# INACTIVE    1897
# ACTIVE       623
# UNKNOWN      118
# Name: count, dtype: int64

# %%
status_percent.round(2)
# Out:
# status
# INACTIVE    71.91
# ACTIVE      23.62
# UNKNOWN      4.47
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))
status_counts.plot(kind="bar")
plt.title("Job Status Distribution")
plt.ylabel("Number of Jobs")
plt.xlabel("Status")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# We can clearly see that most jobs are **inactive** and historical, given by the fact that ~72% of all job entries are of status inactive. This however is a logical consequence of CV data and confirms to us that the CVs contain rich career history. This is important to note because this makes using an extension of incorporating previous jobs very feasible and valuable. Incorporating previous jobs is therefore a well motivated extension, not only because it increases the amount of training data, but more importantly because it provides additional contextual signals that can help disambiguate current roles and improve both department and seniority prediction.
#
# Approximately 24% of jobs are labeled as **active**, while a small fraction (≈4.5%) have status **unknown** likely due to incomplete temporal metadata. This structure supports both current-job prediction and the use of historical jobs for contextual extensions.

# %% [markdown]
# Our first intuition based on common sense and also based on the data (24% of jobs are labeled as active) is that there is 1 active job per CV. To support this intuition we take a look at the distribution of active jobs per CV:

# %%
active_jobs_per_cv_full = (
    eda_df
    .groupby("cv_id")["status"]
    .apply(lambda x: (x == "ACTIVE").sum())
)

# %%
active_jobs_per_cv_full.value_counts().sort_index()
# Out:
# status
# 0     131
# 1     380
# 2      78
# 3      10
# 4       3
# 5       4
# 7       1
# 8       1
# 10      1
# Name: count, dtype: int64

# %% [markdown]
# Most CVs (380) have exactly 1 active job and represents the largest group.
# However, we also have a high amount of CVs (131) without a current job.
# Some have 2 (78) or 3 (10), and there are some minor edge cases with a maximum 10 current jobs in a CV.

# %% [markdown]
# Conditioned on CVs that contain at least one ACTIVE job, we further examine how many concurrent ACTIVE jobs exist per CV to assess the prevalence of multi-role cases:

# %%
active_jobs_per_cv = (
    eda_df[eda_df["status"] == "ACTIVE"]
    .groupby("cv_id")
    .size()
)

active_jobs_per_cv.describe()
# Out:
# count    478.000000
# mean       1.303347
# std        0.833037
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       10.000000
# dtype: float64

# %% [markdown]
# - there are 478 CVs that have at least 1 active job
# - the mean active job per CV is 1.3 and the median is 1 active job per CV
# - there is a Maximum of 10 active jobs per CV
#
# -> most CVs have exactly one active job, while multiple active jobs are a minority case

# %%
active_jobs_per_cv.value_counts().sort_index()
# Out:
# 1     380
# 2      78
# 3      10
# 4       3
# 5       4
# 7       1
# 8       1
# 10      1
# Name: count, dtype: int64

# %% [markdown]
# - 380 CVs have exactly 1 active job
# - only 98 CVs have more than 1 active job

# %% [markdown]
# An analysis of the number of active jobs per CV shows that while most individuals (≈80%) have exactly one current position, a substantial minority have multiple active jobs. This indicates that the concept of a single current job is generally valid but not universal.
# Because the task requires predicting the characteristics of the current job, it is ambiguous when multiple active positions are present. Therefore we exclude those CVs in the prediciton.

# %% [markdown]
# ## 2.4 Department vs job status

# %%
pd.crosstab(
    eda_df["status"],
    eda_df["department"],
    normalize="index"
).round(3)
# Out:
# department  Administrative  Business Development  Consulting  \
# status
# ACTIVE               0.022                 0.032       0.063
# INACTIVE             0.032                 0.031       0.079
# UNKNOWN              0.076                 0.000       0.051
#
# department  Customer Support  Human Resources  Information Technology  \
# status
# ACTIVE                 0.010            0.026                   0.100
# INACTIVE               0.022            0.026                   0.127
# UNKNOWN                0.008            0.034                   0.085
#
# department  Marketing  Other  Project Management  Purchasing  Sales
# status
# ACTIVE          0.035  0.552               0.063       0.024  0.074
# INACTIVE        0.057  0.438               0.071       0.030  0.089
# UNKNOWN         0.017  0.661               0.017       0.008  0.042

# %% [markdown]
# Status **active** clearly shows a dominance of department Other. After that, IT and Sales are the strongest specific departments. This suggests that current job titles often lack strong department specific signal.
#
# Status **inactive** also has Other dominating but less extreme percentage wise and shows more diversity across departments. Historical jobs show broader departmental diversity than current roles.
#
# Status **unknown** is extremely dominated by Other and has a sparse representation elsewhere. These unknown status jobs lack sufficient structure for reliable department inference.
#
# The distribution of department labels differs by job status. Active jobs are strongly dominated by the Other”category, whereas inactive jobs exhibit greater departmental diversity. This suggests that current job titles alone often provide limited department-specific information and motivates the incorporation of previous job history to improve department prediction.

# %% [markdown]
# ## 2.5 Seniority vs job status

# %%
pd.crosstab(
    eda_df["status"],
    eda_df["seniority"],
    normalize="index"
).round(3)
# Out:
# seniority  Director  Junior   Lead  Management  Professional  Senior
# status
# ACTIVE        0.055   0.019  0.201       0.308         0.347   0.071
# INACTIVE      0.055   0.114  0.167       0.104         0.495   0.064
# UNKNOWN       0.017   0.017  0.153       0.237         0.542   0.034

# %% [markdown]
# among active jobs:
# - Professional  34.7%
# - Management   30.8%
# - Lead         20.1%
# - Senior        7.1%
# - Director      5.5%
# - Junior        1.9%
#
# **Active** jobs are strongly skewed toward mid to high seniority levels. Junior roles are rare among current jobs. Management + Lead together alone represent ≈51%. Current positions tend to represent later career stages.
#
# Junior roles are much more common in **inactive** jobs. Earlier career stages are more prevalent in past positions.

# %% [markdown]
# ## 2.6 How often people change departments
#
# We want to analyse if we can assume that it is rather unlikely that persons change the department over time.

# %% [markdown]
# Note that we explained before in our data that the job order is:
# - job_index = 0 is the most recent job
# - higher job_index = older job

# %%
def count_department_changes(cv_df):
    cv_df = cv_df.sort_values("job_index")
    return (cv_df["department"] != cv_df["department"].shift()).sum() - 1

# %% [markdown]
# - We compare each job to the previous one
# - Count how often the department changes
# - Subtract 1 because the first job has no previous comparison

# %%
department_changes_per_cv = (
    eda_df
    .groupby("cv_id")
    .apply(count_department_changes)
)
# Out:
# /tmp/ipython-input-2448362840.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(count_department_changes)

# %%
department_changes_per_cv.describe()
# Out:
# count    609.000000
# mean       1.530378
# std        2.165705
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max       24.000000
# dtype: float64

# %% [markdown]
# - Median = 1 department change → most people change department once
# - 25% have 0 changes → strong department stability for a large subset
# - Mean > median → skewed by a small number of highly mobile careers
# - Max = 24 → extreme outlier case, but not representative

# %%
department_changes_per_cv.value_counts().sort_index()
# Out:
# 0     288
# 1      94
# 2      78
# 3      57
# 4      31
# 5      25
# 6      21
# 7       4
# 8       7
# 9       2
# 10      1
# 24      1
# Name: count, dtype: int64

# %% [markdown]
# Strong stability for many people
# - 288 CVs (≈47%) never change department
# - 382 CVs (≈63%) change at most once
#
# -> Strong stability for many people. This supports the assumption of department stability for most people
#
# -> But department change is not completely rare, ~37% changed department multiple times

# %% [markdown]
# An analysis of department transitions over time shows that nearly half of all individuals never change departments, and approximately two-thirds change department at most once throughout their recorded career history. While department changes do occur, particularly for a subset of highly mobile careers, the overall pattern indicates substantial departmental stability. This supports the use of previous job information as contextual signal for predicting the department of the current role.

# %% [markdown]
# ## 2.7 Seniority progression over time

# %% [markdown]
# For that we map seniority manually to an ordinal scale:
# - Junior = 0
# - Professional = 1
# - Senior = 2
# - Lead = 3
# - Management = 4
# - Director = 5

# %%
seniority_order = {
    "Junior": 0,
    "Professional": 1,
    "Senior": 2,
    "Lead": 3,
    "Management": 4,
    "Director": 5
}

eda_df["seniority_level"] = eda_df["seniority"].map(seniority_order)

# %% [markdown]
# we check seniority changes between consecutive jobs:

# %%
def count_seniority_direction(cv_df):
    cv_df = cv_df.sort_values("job_index")
    diffs = cv_df["seniority_level"].diff()

    return pd.Series({
        "increases": (diffs > 0).sum(),
        "decreases": (diffs < 0).sum(),
        "stays_same": (diffs == 0).sum()
    })

# %%
seniority_changes = (
    eda_df
    .groupby("cv_id")
    .apply(count_seniority_direction)
)
# Out:
# /tmp/ipython-input-1575705887.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(count_seniority_direction)

# %%
seniority_changes.sum()
# Out:
# increases      376
# decreases      631
# stays_same    1022
# dtype: int64

# %% [markdown]
# - stability dominates
# - decreases exist and are common
# - increases exist but are not the majority
#
# -> seniority tends to be stable with occasional upward or downward transitions
#
# An analysis of seniority transitions between consecutive jobs shows that most career moves are lateral, with seniority remaining unchanged in the majority of cases. While upward transitions do occur, downward transitions are also present, reflecting non-linear career paths and role changes across organizations.

# %% [markdown]
# What this implies for modeling (later, not now)
# Later, this supports:
# - using previous seniority levels as features
# - not enforcing monotonic constraints
# - letting the model learn patterns instead of rules
#
# This aligns with:
# - approach 4 (programmatic labeling)
# - approach 5 (feature engineering)
# - approach 6 (TF–IDF models)

# %% [markdown]
# ## 2.8 Job Title
#
# Since all our baseline and ML approaches use the job titles as predictor, we must understand their overall structure:
# - how long they are
# - how diverse / noisy they are linguistically
#
# This can later help us
# help strengthen the argument that:
# - rule-based baseline is likely limited
# - text-based ML models are likely necessary
# - some errors might be unavoidable due to noise

# %% [markdown]
# ### 2.8.1 Job title length distribution
#
# Job title length tells us:
# - how much information is available per sample
# - whether titles are mostly short or descriptive
# - Short titles → ambiguous
# - Long titles → richer signal but noisier

# %% [markdown]
# we measure:
# - number of characters
# - number of words (word count is usually more interpretable)

# %%
eda_df["title_word_count"] = eda_df["position"].str.split().str.len()

eda_df["title_word_count"].describe()
# Out:
# count    2638.000000
# mean        3.044731
# std         2.124734
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         4.000000
# max        17.000000
# Name: title_word_count, dtype: float64

# %%
plt.figure(figsize=(8, 4))
eda_df["title_word_count"].hist(bins=30)
plt.title("Job Title Length Distribution (Word Count)")
plt.xlabel("Number of Words in Job Title")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most job titles are short (1-3 words)
# - At least 50% of titles have only 1–2 words
# - At least 75% have ≤4 words
# - A non-trivial number are single-word titles
# - Mean is 3 words

# %% [markdown]
# This already tells us that the rulebased baseline might struggle. Rule-based matching relies on explicit keywords and stable patterns. Short titles (1-3 words) however lack context, are reused across departments and could often omit seniority or domain. Therefore, the rule.based baseline overpredict dominant classes (“Other”, “Professional”) and could fail on ambiguous titles

# %% [markdown]
# ### 2.8.2 Language and character diversity of job titles

# %% [markdown]
# To not overkill the analysis, we begin by looking at a random sample of about 100 jobs to get an overall view on the diversity of languages and characters in the titles.
#
# Looking at the sample, we primarily inspect the following:
# - analyse if non-English titles exist
# - look for special characters and whitespacing

# %%
eda_df["position"].sample(100, random_state=42).tolist()
# Out:
# ['Design & Communications Manager',
#  'Teamleiter Steuern',
#  'Senior Financial Crimes Investigator',
#  'Senior Electronics Engineer',
#  'Financial Accountant',
#  'Financial Analyst',
#  'Night Shift Operator',
#  'Associate Partner',
#  'Projectorganisator',
#  'Key Account / Project Manager',
#  'Research Assistant',
#  'officer',
#  'Associate Consultant',
#  'Technische Assistenz',
#  'Kaufmännischer Leiter',
#  'Management Consultant Information Security and Privacy',
#  'Deputy Director "Cognitive Computing and Medical Imaging"',
#  'Leistungssachbearbeiter SGB II',
#  'stellvertretender Referatsleiter',
#  'Teacher: History, Ethics, French',
#  'Director',
#  'Kfm. Leiter Niederlassung SüdWest der SPIE Energy Solutions GmbH',
#  'Recruiter',
#  'Maitre d’hotel Kieffer traiteur',
#  'Blockchain Strategist',
#  'Head of Logistics',
#  'Fachlead / Professional Lead Bid & Offer Management',
#  'Innovation Lead',
#  'Versicherungskaufmann',
#  'Managing Director Autotech Engineering (Shanghai), R&D Director China of BU Chassis and BiW, Gestamp',
#  'Senior UX Designer',
#  'Musiklehrer (StR z. A.)',
#  'Trainer communicatieve vaardigeheden',
#  'Abteilungsleiter Teppiche/Heimtextilien',
#  'Chief Buyer',
#  'Cyber Security Analyst - Senior',
#  'Consultant - Düsseldorf / Chicago Office',
#  'Co-Founder and CEO',
#  'Consulting Manager and Head of EMEA Expert Consulting',
#  'Application Development Specialist & Technician Supervisor',
#  'Executive Director at Adform s.r.o.',
#  'Kaufmännischer Auszubildender',
#  'Behandelfunctionaris Omzetbelasting/Overdrachtsbelasting',
#  'European Service Manager',
#  'Consultant',
#  'Assistant',
#  'Consultant',
#  'Managing Director',
#  'Joint Venture Indonesien',
#  'Scientific Researcher',
#  'IT ServiceDesk',
#  'Digital Performance Director',
#  'Fachgebietsleiter Hochenergiesysteme',
#  'Research Associate',
#  'IT Manager',
#  'Projektleiterin Bildung',
#  'Trainee',
#  'Praktikant',
#  'Department Lead and Replenishment Buyer',
#  'Technical Transfer Leader',
#  'IT-Leiter',
#  'Studiengangsprecher des Masterstudiengangs Energiesystemtechnik',
#  'Business Process Management Consultant',
#  'IT Business Analyst',
#  'Mechanical Engineer',
#  'Transport Manager',
#  'Geschäftsführer, CMO',
#  'Sr. Application Software Engineer',
#  'Magasinier',
#  'Zweigstellen Koordinator',
#  'Technical Support Advisor',
#  'Attorney',
#  'Director, Assistant Treasurer & Fuel',
#  'Research Development Group Manager',
#  'vedoucí účetní',
#  'Co-Founder',
#  'Entwurfsarchitekt, Projektleiter',
#  'Founder and President',
#  'Originalare/Final artist',
#  'general mgr',
#  'Meister Fluggerät (MiG 29, EF2000)',
#  'Senior Project Leader',
#  'Managing Director',
#  'Gruppenleiter Entwicklung',
#  'Finance and HR',
#  'Regional Director',
#  'Human Resources',
#  'Head of Cargo Northeast USA & Canada',
#  'Director, Element Division',
#  'Network Administrator',
#  'IT Infrastructure Planning Specialist',
#  'Human Resources Generalist',
#  'Co-CEO',
#  'FX Sales',
#  'Chief Commercial Officer',
#  'Entwicklungs Ingenieur',
#  'Leitende Stelle Marketing & Vertrieb',
#  'Beamter',
#  'Software Craftsman',
#  'Ausbilder Lager/Handel']

# %% [markdown]
# - we have non-English titles (in this sample many are English and German)
# - we have special characters (such as /, (), -, &) and whitespacing

# %% [markdown]
# We also check for non-ASCII characters

# %%
eda_df["contains_non_ascii"] = eda_df["position"].apply(
    lambda x: any(ord(c) > 127 for c in x)
)

eda_df["contains_non_ascii"].value_counts(normalize=True).round(3)
# Out:
# contains_non_ascii
# False    0.889
# True     0.111
# Name: proportion, dtype: float64

# %% [markdown]
# - 88.9% → ASCII-only titles
# - 11.1% → titles with non-ASCII characters
#
# Approximately 11% of job titles contain non-ASCII characters, indicating the presence of non-English or language-specific titles. This linguistic diversity introduces additional variability and noise, particularly for rule-based approaches that rely on fixed keyword lists. This indicates that robust NLP-based models might be better suited to handle multilingual and heterogeneous job title data.

# %% [markdown]
# Non-ASCII characters typically indicate:
# - non-English titles (e.g. German, French, Spanish)
# - localized spellings (ä, ö, ü, ß, é, ñ, etc.)
# - mixed-language titles
#
# So this result tells us:
# - At least ~11% of job titles are non-English or language-specific.
# - This is a lower bound, not an upper bound: English titles can still exist in other languages and ASCII-only does not mean “English”

# %% [markdown]
# # 3. Dataset Construction Functions
#
# Since different modeling approaches require the data in different representations, we define reusable dataset functions that take the annotated dataset as input so that:
# - every model uses the same data definition
# - comparisons are fair
# - extensions are switchable and comparable
#
# This ensures that all models are trained on the same data definition, enabling fair and reproducible comparisons. Two dataset variants are provided:
# - a baseline version using only the current job
# - an extended version incorporating additional CV context
#
# The functions define the basic input scope (baseline vs. extension), while all feature engineering and model-specific transformations are applied afterwards, allowing full flexibility for future modeling approaches.

# %% [markdown]
# ## 3.1 Baseline Function (no extension)
#
# - x = current job only
#
# This function provides the data to only look at the current job title to predict department and seniority.
# In the data "current job" means that the *status* is *active*. And the job is found in the column *position*. We have 2 y variables, one is *department* and the other one *seniority*. Furthermore, we add the *cv_id* as metadata to enable grouping, evaluation and error analysis at the CV level without being used as a model feature.

# %%
def get_baseline_dataset(df):
    current = df[df["status"] == "ACTIVE"].copy()
    X = current["position"]
    y_department = current["department"]
    y_seniority = current["seniority"]
    meta = current[["cv_id"]]
    return X, y_department, y_seniority, meta

# %% [markdown]
# ## 3.2 Extension function (including previous jobs)
#
# - x = current job + other CV info
#
# This function provides the data to look at the current job title and more information from the CVs to predict department and seniority.
# In this extended function, we include job titles from previous positions in addition to the current role. This is motivated by the EDA results. The majority of available job entries are historical positions (~72% of jobs are inactive, CVs have multiple historical jobs, ~24% of jobs are active), incorporating previous job titles therefore allows us to exploit substantially more contextual information per CV.

# %%
def get_extended_dataset(df):
    rows = []

    for cv_id, cv_df in df.groupby("cv_id"):

        # Keep only jobs with known temporal meaning
        cv_df = cv_df[cv_df["status"].isin(["ACTIVE", "INACTIVE"])]

        # Sort so that lower job_index = more recent job
        cv_df = cv_df.sort_values("job_index")

        # Identify current job
        active_jobs = cv_df[cv_df["status"] == "ACTIVE"]

        # Require exactly one current job
        if len(active_jobs) != 1:
            continue

        current = active_jobs.iloc[0]

        # Previous jobs = INACTIVE and older than current
        history = cv_df[
            (cv_df["status"] == "INACTIVE") &
            (cv_df["job_index"] > current["job_index"])
        ]

        # Extended text input: current job + previous jobs
        text = current["position"]
        if len(history) > 0:
            text += " | " + " | ".join(history["position"])

        rows.append({
            "cv_id": cv_id,
            "text": text,
            "department": current["department"],
            "seniority": current["seniority"],
        })

    ext = pd.DataFrame(rows)

    X = ext["text"]
    y_department = ext["department"]
    y_seniority = ext["seniority"]
    meta = ext[["cv_id"]]

    return X, y_department, y_seniority, meta

# %% [markdown]
# #  4. Baseline
#
# As the baseline, we implement a rule-based classifier that assigns department and seniority labels by matching job titles against the predefined label lists
#
# the predefined label lists are:
# - department_df
# - seniority_df

# %% [markdown]
# **Rule logic**
#
# Substring matching against predefined label lists is used for the rule-based baseline. Only minimal syntactic normalization is applied, while semantic transformations are deliberately avoided to preserve the baseline’s role as a simple, non-learning reference model.

# %%
department_df.head()
# Out:
#                                                text               label
# 0                   Adjoint directeur communication           Marketing
# 1                     Advisor Strategy and Projects  Project Management
# 2                               Beratung & Projekte  Project Management
# 3                      Beratung & Projektmanagement  Project Management
# 4  Beratung und Projektmanagement kommunale Partner  Project Management

# %%
seniority_df.head()
# Out:
#                                 text   label
# 0                            Analyst  Junior
# 1                 Analyste financier  Junior
# 2  Anwendungstechnischer Mitarbeiter  Junior
# 3               Application Engineer  Senior
# 4              Applications Engineer  Senior

# %% [markdown]
# ## 4.1 Data Preparation

# %% [markdown]
# ### 4.1.1 Normalization function

# %% [markdown]
# For rule-based matching, job titles and label-list entries are normalized using lowercasing and whitespace stripping before applying simple substring matching:
#
# - lowercasing
# - stripping whitespace and collapsing multiple internal spaces
#
# This is done to avoid any accidental mismatching due to lower/uppercasing or spacing (spaces, tabs, line breaks).
#
# We want to make sure the normalization does not alter meaning or generalize semantics, but simply removes formatting noise. Therefore, no further text processing is applied in order to keep the baseline fully interpretable.
# We apply the same normalization to CV titles and the label-list titles.

# %%
def normalize_text(text):
    if not isinstance(text, str):
        return ""

    text = text.lower().strip()
    text = " ".join(text.split())
    return text

# %% [markdown]
# The function is directly applied to the label lists and will be build into the rule-based prediction function for the dataset.

# %%
department_df["text_norm"] = department_df["text"].apply(normalize_text)
seniority_df["text_norm"] = seniority_df["text"].apply(normalize_text)

# %% [markdown]
# ### 4.1.2 Prediction Functions
#
# Our rule-based matching functions implement a rule-based classifier using the provided department and seniority label list where job titles are matched via substring rules.
# Unmatched titles to departments are assigned to the label ‘Other’. For seniority we explicitly use "Professional" as default for unmatched titles, because no label such as "Other" exists in seniority. Since this is the most frequent seniority class, it is used as the fallback label to avoid artificially inflating rare classes.

# %%
def predict_department_rule_based(title, department_df):
    title_norm = normalize_text(title)

    for _, row in department_df.iterrows():
        if row["text_norm"] in title_norm:
            return row["label"]

    return "Other"

# %%
def predict_seniority_rule_based(title, seniority_df):
    title_norm = normalize_text(title)

    for _, row in seniority_df.iterrows():
        if row["text_norm"] in title_norm:
            return row["label"]

    # Default fallback if nothing matches
    return "Professional"

# %% [markdown]
# ### 4.1.3 Evaluation Function

# %% [markdown]
# We use the following metrics to evaluate and compare the baseline model with the future ML models:
#
# - **Accuracy:** shows the overall fraction of correctly classified samples
# - **macro-averaged F1-Score:** is the harmonic mean of precision and recall, computed independently for each class and averaged across classes. This metric is particularly important due to the strong class imbalance in both department and seniority labels, as it ensures that performance on minority classes is weighted equally.
#
# Together, these metrics allow us to assess how often each model is correct overall (accuracy) and how well it performs across all classes, including rare ones (macro F1-score).

# %%
from sklearn.metrics import accuracy_score, f1_score

def evaluate_predictions(y_true, y_pred):
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro")
    }

# %% [markdown]
# ## 4.2 Rule-based Matching

# %% [markdown]
# The rule-based matching baseline does not involve training and is therefore evaluated on the full dataset, whereas all learning-based models will be evaluated out-of-sample using a fixed train–test split to ensure fair comparison

# %%
X_base, y_dep_base, y_sen_base, meta_base = get_baseline_dataset(jobs_annotated_df)

# %%
X_base.head()
# Out:
# 0         Prokurist
# 1               CFO
# 2    Betriebswirtin
# 3       Prokuristin
# 4               CFO
# Name: position, dtype: object

# %%
y_dep_base.head()
# Out:
# 0    Other
# 1    Other
# 2    Other
# 3    Other
# 4    Other
# Name: department, dtype: object

# %%
y_sen_base.head()
# Out:
# 0      Management
# 1      Management
# 2    Professional
# 3      Management
# 4      Management
# Name: seniority, dtype: object

# %%
X_ext, y_dep_ext, y_sen_ext, meta_ext = get_extended_dataset(jobs_annotated_df)

# %% [markdown]
# ### 4.2.1 Rule-based Department Matching

# %% [markdown]
# **Only Current Job**

# %%
y_dep_pred_base = X_base.apply(
    lambda title: predict_department_rule_based(title, department_df)
)

# %%
metrics_dep_base = evaluate_predictions(y_dep_base, y_dep_pred_base)
metrics_dep_base
# Out:
# {'accuracy': 0.622792937399679, 'macro_f1': 0.3996236061634464}

# %% [markdown]
# **With Extension**

# %%
y_dep_pred_ext = X_ext.apply(
    lambda title: predict_department_rule_based(title, department_df)
)

# %%
metrics_dep_ext = evaluate_predictions(y_dep_ext, y_dep_pred_ext)
metrics_dep_ext
# Out:
# {'accuracy': 0.4368421052631579, 'macro_f1': 0.30458751010937224}

# %% [markdown]
# ### 4.2.2 Rule-based Seniority Matching

# %% [markdown]
# **Only Current Job**

# %%
y_sen_pred_base = X_base.apply(
    lambda title: predict_seniority_rule_based(title, seniority_df)
)

# %%
metrics_sen_base = evaluate_predictions(y_sen_base, y_sen_pred_base)
metrics_sen_base
# Out:
# {'accuracy': 0.5666131621187801, 'macro_f1': 0.4280514741188899}

# %% [markdown]
# **With Extension**

# %%
y_sen_pred_ext = X_ext.apply(
    lambda title: predict_seniority_rule_based(title, department_df)
)

# %%
metrics_sen_ext = evaluate_predictions(y_sen_ext, y_sen_pred_ext)
metrics_sen_ext
# Out:
# {'accuracy': 0.13421052631578947, 'macro_f1': 0.02639751552795031}

# %% [markdown]
# For the rule-based baseline, incorporating historical job titles leads to a decrease in both accuracy and macro F1-score. This suggests that simple keyword-matching approaches are sensitive to additional, potentially conflicting signals introduced by past roles. The result highlights the limitations of non-learning methods in exploiting richer contextual information and motivates the use of learning-based models for handling extended inputs
# Adding historical context alone does not help a simple rule-based system and can even degrade performance, highlighting the limitations of non-learning approaches.

# %% [markdown]
# # 5. Preparation for ML models

# %% [markdown]
# To compare all models fairly, the following must be identical for all ML models:
# - Same dataset (baseline vs extension handled separately)
# - Same train/test split
# - Same random seed
# - Same evaluation metrics
# - Same label definitions
#
# This means that we define the split once and reuse it everywhere.

# %% [markdown]
# ## 5.1 Split Function
#
# This function splits the data on the CV-level, the not job-level. It is important to split by CV and not by individual job rows, because otherwise the same person would appear in train and test and would therefore cause data leakage.
#
# - split on *cv_id*

# %%
from sklearn.model_selection import train_test_split

def train_test_split_by_cv(X, y_dep, y_sen, meta, test_size=0.2, random_state=42):
    """
    Perform train-test split at CV level to avoid leakage.
    """

    df = pd.concat(
        [X, y_dep, y_sen, meta],
        axis=1
    )

    unique_cvs = df["cv_id"].unique()

    train_cvs, test_cvs = train_test_split(
        unique_cvs,
        test_size=test_size,
        random_state=random_state
    )

    train_df = df[df["cv_id"].isin(train_cvs)]
    test_df = df[df["cv_id"].isin(test_cvs)]

    return (
        train_df["text"], test_df["text"],
        train_df["department"], test_df["department"],
        train_df["seniority"], test_df["seniority"],
    )

# %% [markdown]
# ## 5.2 ML Runner Function

# %%
def run_ml_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return evaluate_predictions(y_test, y_pred)

# %% [markdown]
# For each model we do:
#
# - one run with *get_baseline_dataset*
# - one run with *get_extended_dataset*
#
# with this code:
#
# ```
# X, y_dep, y_sen, meta = get_..._dataset(jobs_annotated_df)
#
# X_train, X_test, y_dep_train, y_dep_test, y_sen_train, y_sen_test = (
#     train_test_split_by_cv(X, y_dep, y_sen, meta)
# )
# ```

# %% [markdown]
# ## 5.3 Results comparison table
#
# The results table must capture and compare compare across:
# - Model
# - Target (department vs seniority)
# - Extension (no / yes)
# - Metrics (accuracy, macro F1)
#
# → each row is one experiment

# %%
results = []

def add_result(model_name, target, extension, metrics):
    results.append({
        "model": model_name,
        "target": target,
        "extension": extension,
        "accuracy": metrics["accuracy"],
        "macro_f1": metrics["macro_f1"]
    })

# %% [markdown]
# at any point, we can then:

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 5.3.1 Adding Rule-based Matching Results

# %%
add_result(
    model_name="Rule-based",
    target="department",
    extension="no",
    metrics={"accuracy": 0.6228, "macro_f1": 0.3996}
)

add_result(
    model_name="Rule-based",
    target="department",
    extension="yes",
    metrics={"accuracy": 0.4368, "macro_f1": 0.3046}
)

add_result(
    model_name="Rule-based",
    target="seniority",
    extension="no",
    metrics={"accuracy": 0.5666, "macro_f1": 0.4281}
)

add_result(
    model_name="Rule-based",
    target="seniority",
    extension="yes",
    metrics={"accuracy": 0.1342, "macro_f1": 0.0264}
)

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#         model      target extension  accuracy  macro_f1
# 0  Rule-based  department        no    0.6228    0.3996
# 1  Rule-based  department       yes    0.4368    0.3046
# 2  Rule-based   seniority        no    0.5666    0.4281
# 3  Rule-based   seniority       yes    0.1342    0.0264

# %% [markdown]
# **How we judge “better or worse” later (quick reminder)**
#
# After we compute metrics:
# - rule-based baseline (4 runs)
# - ML models (with proper train/test)
#
# We compare numbers:
# - accuracy
# - macro F1
#
# If ML > rule-based → success
#
# If extension > baseline → extension justified

# %% [markdown]
# **Next Step: TF–IDF + Logistic Regression Model (approach 6: simple interpretable baseline) !**
#
# because this immediately follows the baseline as a first ML model
