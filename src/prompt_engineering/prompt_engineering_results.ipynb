# %%
import pandas as pd

# %%
test_data = pd.read_csv("../../data/processed/jobs_annotated_active.csv")
prediction_df = pd.read_csv("../../data/results/gemini_results.csv")

# %%
test_data.head()
# Out:
#    row_id  cv_id  job_index       organization        position startDate  \
# 0       0      0          0  Depot4Design GmbH       Prokurist   2019-08
# 1       1      0          1  Depot4Design GmbH             CFO   2019-07
# 2       2      0          2  Depot4Design GmbH  Betriebswirtin   2019-07
# 3       3      0          3  Depot4Design GmbH     Prokuristin   2019-07
# 4       4      0          4  Depot4Design GmbH             CFO   2019-07
#
#    endDate  status department     seniority
# 0      NaN  ACTIVE      Other    Management
# 1      NaN  ACTIVE      Other    Management
# 2      NaN  ACTIVE      Other  Professional
# 3      NaN  ACTIVE      Other    Management
# 4      NaN  ACTIVE      Other    Management

# %%
prediction_df.head()
# Out:
#    row_id        position  seniority            department
# 0       0       Prokurist        5.0                 Other
# 1       1             CFO        6.0                 Other
# 2       2  Betriebswirtin        2.0  Business Development
# 3       3     Prokuristin        5.0                 Other
# 4       4             CFO        6.0                 Other

# %%
# merge into results -> merge on same row_id, keep position of test_data and rename seniority of prediction_df to predicted_seniority and rename department of prediction_df to predicted_department
# rename seniority in prediction_df to predicted_seniority and rename department in prediction_df to predicted_department
prediction_df = prediction_df.rename(columns={"seniority": "predicted_seniority", "department": "predicted_department"})

results_df = pd.merge(test_data, prediction_df[["row_id", "predicted_seniority", "predicted_department"]], on="row_id", how="left")

# drop coluumns job_index, startDate, endDate, status
results_df = results_df.drop(columns=["job_index", "startDate", "endDate", "status"])
results_df.head()
# Out:
#    row_id  cv_id       organization        position department     seniority  \
# 0       0      0  Depot4Design GmbH       Prokurist      Other    Management
# 1       1      0  Depot4Design GmbH             CFO      Other    Management
# 2       2      0  Depot4Design GmbH  Betriebswirtin      Other  Professional
# 3       3      0  Depot4Design GmbH     Prokuristin      Other    Management
# 4       4      0  Depot4Design GmbH             CFO      Other    Management
#
#    predicted_seniority  predicted_department
# 0                  5.0                 Other
# 1                  6.0                 Other
# 2                  2.0  Business Development
# 3                  5.0                 Other
# 4                  6.0                 Other

# %%
# encode seniority levels to numeric values

seniority_map = {
    "Junior": 1.0,
    "Professional": 2.0,   # kommt im Train nicht vor, ist ok
    "Senior": 3.0,
    "Lead": 4.0,
    "Management": 5.0,
    "Director": 6.0
}

results_df["seniority"] = results_df["seniority"].map(seniority_map)

results_df.head()
# Out:
#    row_id  cv_id       organization        position department  seniority  \
# 0       0      0  Depot4Design GmbH       Prokurist      Other        5.0
# 1       1      0  Depot4Design GmbH             CFO      Other        5.0
# 2       2      0  Depot4Design GmbH  Betriebswirtin      Other        2.0
# 3       3      0  Depot4Design GmbH     Prokuristin      Other        5.0
# 4       4      0  Depot4Design GmbH             CFO      Other        5.0
#
#    predicted_seniority  predicted_department
# 0                  5.0                 Other
# 1                  6.0                 Other
# 2                  2.0  Business Development
# 3                  5.0                 Other
# 4                  6.0                 Other

# %%
# make statistic of how much percent of seniority == predicted_seniority
correct_seniority = results_df[results_df["seniority"] == results_df["predicted_seniority"]]
accuracy_seniority = len(correct_seniority) / len(results_df) * 100
print(f"Seniority Prediction Accuracy: {accuracy_seniority:.2f}%")
# Out:
# Seniority Prediction Accuracy: 51.04%

# %%
# show me where seniority != predicted_seniority
incorrect_seniority = results_df[results_df["seniority"] != results_df["predicted_seniority"]]
incorrect_seniority.head(10)
# Out:
#     row_id  cv_id                         organization  \
# 1        1      0                    Depot4Design GmbH
# 4        4      0                    Depot4Design GmbH
# 5        5      1                   Computer Solutions
# 8        8      3  Air & Ground Operations Consultancy
# 9        9      3                   Viajes Oceano S.L.
# 10      10      4    Himmelstalunds Utbildningscentrum
# 11      11      5         FSD Fahrzeugsystemdaten GmbH
# 14      14      8                        PhoboSys GmbH
# 15      15     11                Twentieth Century Fox
# 16      16     11                                 Sony
#
#                     position              department  seniority  \
# 1                        CFO                   Other        5.0
# 4                        CFO                   Other        5.0
# 5        Solutions Architect  Information Technology        2.0
# 8          Gerente comercial                   Sales        4.0
# 9        Administrador Unico          Administrative        2.0
# 10  APL-ansvarig, samordning          Administrative        4.0
# 11     Kaufmännischer Leiter                   Sales        4.0
# 14         Managing Director                   Other        5.0
# 15              Set Lighting                   Other        2.0
# 16              Set Lighting                   Other        2.0
#
#     predicted_seniority    predicted_department
# 1                   6.0                   Other
# 4                   6.0                   Other
# 5                   3.0  Information Technology
# 8                   5.0                   Sales
# 9                   5.0          Administrative
# 10                  2.0                   Other
# 11                  5.0                   Other
# 14                  6.0                   Other
# 15                  1.0                   Other
# 16                  1.0                   Other

# %%
# now do the same for department
correct_department = results_df[results_df["department"] == results_df["predicted_department"]]
accuracy_department = len(correct_department) / len(results_df) * 100
print(f"Department Prediction Accuracy: {accuracy_department:.2f}%")
# Out:
# Department Prediction Accuracy: 72.87%

# %%
# show me where department != predicted_department
incorrect_department = results_df[results_df["department"] != results_df["predicted_department"]]
incorrect_department.head(10)
# Out:
#     row_id  cv_id                       organization  \
# 2        2      0                  Depot4Design GmbH
# 10      10      4  Himmelstalunds Utbildningscentrum
# 11      11      5       FSD Fahrzeugsystemdaten GmbH
# 21      21     13         Landeshauptstadt Wiesbaden
# 28      28     21            Gebrüder Weiß & Cie. KG
# 32      32     27                       Stork Lijmen
# 34      34     27            ESBA Horti Solutions BV
# 43      43     39                Quest ontheFRONTIER
# 52      52     49             Wehner Consulting GmbH
# 57      57     55                          myclimate
#
#                              position      department  seniority  \
# 2                      Betriebswirtin           Other        2.0
# 10           APL-ansvarig, samordning  Administrative        4.0
# 11              Kaufmännischer Leiter           Sales        4.0
# 21     Leistungssachbearbeiter SGB II           Other        2.0
# 28  Geschäftsführender Gesellschafter           Other        5.0
# 32                           Co-Owner           Other        5.0
# 34                        CEO/Founder           Other        5.0
# 43         Human Resources Consultant      Consulting        2.0
# 52                    Geschäftsführer           Other        5.0
# 57            Projektleiterin Bildung           Other        4.0
#
#     predicted_seniority  predicted_department
# 2                   2.0  Business Development
# 10                  2.0                 Other
# 11                  5.0                 Other
# 21                  2.0        Administrative
# 28                  6.0  Business Development
# 32                  5.0  Business Development
# 34                  6.0  Business Development
# 43                  2.0       Human Resources
# 52                  5.0  Business Development
# 57                  4.0    Project Management
