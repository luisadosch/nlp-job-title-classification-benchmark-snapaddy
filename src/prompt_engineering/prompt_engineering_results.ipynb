# %%
import pandas as pd

# %%
test_data = pd.read_csv("../../data/processed/jobs_annotated_active.csv")
prediction_df = pd.read_csv("../../data/results/gemini_results.csv")

# %%
test_data.head()
# Out:
#    row_id  cv_id  job_index       organization        position startDate  \
# 0       0      0          0  Depot4Design GmbH       Prokurist   2019-08
# 1       1      0          1  Depot4Design GmbH             CFO   2019-07
# 2       2      0          2  Depot4Design GmbH  Betriebswirtin   2019-07
# 3       3      0          3  Depot4Design GmbH     Prokuristin   2019-07
# 4       4      0          4  Depot4Design GmbH             CFO   2019-07
#
#    endDate  status department     seniority
# 0      NaN  ACTIVE      Other    Management
# 1      NaN  ACTIVE      Other    Management
# 2      NaN  ACTIVE      Other  Professional
# 3      NaN  ACTIVE      Other    Management
# 4      NaN  ACTIVE      Other    Management

# %%
prediction_df.head()
# Out:
#    row_id        position  seniority department
# 0       0       Prokurist        5.0      Other
# 1       1             CFO        5.0      Other
# 2       2  Betriebswirtin        2.0      Other
# 3       3     Prokuristin        5.0      Other
# 4       4             CFO        5.0      Other

# %%
# merge into results -> merge on same row_id, keep position of test_data and rename seniority of prediction_df to predicted_seniority and rename department of prediction_df to predicted_department
# rename seniority in prediction_df to predicted_seniority and rename department in prediction_df to predicted_department
prediction_df = prediction_df.rename(columns={"seniority": "predicted_seniority", "department": "predicted_department"})

results_df = pd.merge(test_data, prediction_df[["row_id", "predicted_seniority", "predicted_department"]], on="row_id", how="left")

# drop coluumns job_index, startDate, endDate, status
results_df = results_df.drop(columns=["job_index", "startDate", "endDate", "status"])
results_df.head()
# Out:
#    row_id  cv_id       organization        position department     seniority  \
# 0       0      0  Depot4Design GmbH       Prokurist      Other    Management
# 1       1      0  Depot4Design GmbH             CFO      Other    Management
# 2       2      0  Depot4Design GmbH  Betriebswirtin      Other  Professional
# 3       3      0  Depot4Design GmbH     Prokuristin      Other    Management
# 4       4      0  Depot4Design GmbH             CFO      Other    Management
#
#    predicted_seniority predicted_department
# 0                  5.0                Other
# 1                  5.0                Other
# 2                  2.0                Other
# 3                  5.0                Other
# 4                  5.0                Other

# %%
# encode seniority levels to numeric values

seniority_map = {
    "Junior": 1.0,
    "Professional": 2.0,   # kommt im Train nicht vor, ist ok
    "Senior": 3.0,
    "Lead": 4.0,
    "Management": 5.0,
    "Director": 6.0
}

results_df["seniority"] = results_df["seniority"].map(seniority_map)

results_df.head()
# Out:
#    row_id  cv_id       organization        position department  seniority  \
# 0       0      0  Depot4Design GmbH       Prokurist      Other        5.0
# 1       1      0  Depot4Design GmbH             CFO      Other        5.0
# 2       2      0  Depot4Design GmbH  Betriebswirtin      Other        2.0
# 3       3      0  Depot4Design GmbH     Prokuristin      Other        5.0
# 4       4      0  Depot4Design GmbH             CFO      Other        5.0
#
#    predicted_seniority predicted_department
# 0                  5.0                Other
# 1                  5.0                Other
# 2                  2.0                Other
# 3                  5.0                Other
# 4                  5.0                Other

# %%
# make statistic of how much percent of seniority == predicted_seniority
correct_seniority = results_df[results_df["seniority"] == results_df["predicted_seniority"]]
accuracy_seniority = len(correct_seniority) / len(results_df) * 100
print(f"Seniority Prediction Accuracy: {accuracy_seniority:.2f}%")
# Out:
# Seniority Prediction Accuracy: 58.43%

# %%
# show me where seniority != predicted_seniority
incorrect_seniority = results_df[results_df["seniority"] != results_df["predicted_seniority"]]
incorrect_seniority.head(40)
# Out:
#      row_id  cv_id                                    organization  \
# 5         5      1                              Computer Solutions
# 8         8      3             Air & Ground Operations Consultancy
# 9         9      3                              Viajes Oceano S.L.
# 10       10      4               Himmelstalunds Utbildningscentrum
# 11       11      5                    FSD Fahrzeugsystemdaten GmbH
# 14       14      8                                   PhoboSys GmbH
# 23       23     15                    ACCOPPIATURA DI ASOLO S.P.A.
# 29       29     22                                    Vorruhestand
# 33       33     27                                    Stork Lijmen
# 42       42     36                               Giesecke+Devrient
# 44       44     41                                   Exelonix GmbH
# 45       45     44                                      FRANK GmbH
# 46       46     45                                   Norra Halland
# 47       47     45                                Levantine Bistro
# 55       55     52                                        noury AG
# 56       56     54             Nordson Adhesive Dispensing Systems
# 64       64     61                               FC Bayern München
# 67       67     63                                 WIDMER Skippers
# 69       69     65  VTA Verfahrenstechnische Anlagen GmbH & Co. KG
# 70       70     66                                          Henkel
# 72       72     68                       Fieldspace Property Group
# 76       76     72                                 Vitamin Well AB
# 79       79     76          Axians NEO Solutions & Technology GmbH
# 81       81     78                          SOR Eğitim Danışmanlık
# 83       83     79       Cranfield University School of Management
# 85       85     80                          Theatergroep Maaistoff
# 88       88     80    Ministerie van Justitie en Veiligheid - NIFP
# 89       89     80                              Theater A la Carte
# 92       92     81                                          Byldis
# 97       97     86          Detlef Meyer "DM108.de - LEH Vertrieb"
# 98       98     89                                         s h e d
# 99       99     90       Paul Schockemöhle Logistics GmbH & Co. KG
# 101     101     93                                     Nagel-Group
# 102     102     95                     Dow Jones Local Media Group
# 103     103     96                                    TTS NMF GmbH
# 104     104     97              MADELINE STUART & ASSOCIATES, INC.
# 105     105     98                           Cassini Consulting AG
# 106     106     99         Dr. Zanda Martens MdB | Büro Düsseldorf
# 107     107    101                                       Stadt Zug
# 108     108    102                                         Aximpro
#
#                                               position  \
# 5                                  Solutions Architect
# 8                                    Gerente comercial
# 9                                  Administrador Unico
# 10                            APL-ansvarig, samordning
# 11                               Kaufmännischer Leiter
# 14                                   Managing Director
# 23                                  Purchasing Manager
# 29                            Bereichsleiter Maschinen
# 33                                                 CEO
# 42                                     Head of HR/CHRO
# 44                                   Managing Director
# 45                                     Product Manager
# 46                                            Reporter
# 47                                  Waiter & Bartender
# 55                         Chief Revenue Officer (CRO)
# 56                        Business Development Manager
# 64                                     Museumspädagoge
# 67                                   Managing Director
# 69                               Maschinenbautechniker
# 70   Technical Customer Service Manager - Flexible ...
# 72                                New Business Manager
# 76                                    Brand Ambassador
# 79                                      Projektmanager
# 81                                        Kurucu Ortak
# 83                           Digital Marketing Manager
# 85                                        Theatermaker
# 88                          Co trainer/trainingsacteur
# 89                              Acteur en theatermaker
# 92             Procurement Manager Strategische Inkoop
# 97                                 Key-Account-Manager
# 98                                   Managing Director
# 99                                   Berufskraftfahrer
# 101                                Key-Account-Manager
# 102                                 Accounting Manager
# 103                         Interims Technical Manager
# 104                                    Project Manager
# 105  Management Consultant Information Security and...
# 106                        Büroleiter | Pressesprecher
# 107                        Departementssekretär Finanz
# 108                                  Managing Director
#
#                  department  seniority  predicted_seniority  \
# 5    Information Technology        2.0                  3.0
# 8                     Sales        4.0                  5.0
# 9            Administrative        2.0                  5.0
# 10           Administrative        4.0                  2.0
# 11                    Sales        4.0                  5.0
# 14                    Other        5.0                  6.0
# 23               Purchasing        2.0                  5.0
# 29                    Other        4.0                  5.0
# 33                    Other        5.0                  NaN
# 42          Human Resources        4.0                  6.0
# 44                    Other        5.0                  6.0
# 45       Project Management        2.0                  5.0
# 46                    Other        2.0                  1.0
# 47                    Other        2.0                  1.0
# 55                    Sales        5.0                  6.0
# 56     Business Development        2.0                  5.0
# 64                    Other        2.0                  1.0
# 67                    Other        5.0                  6.0
# 69                    Other        2.0                  1.0
# 70         Customer Support        4.0                  5.0
# 72     Business Development        4.0                  5.0
# 76                Marketing        2.0                  1.0
# 79       Project Management        2.0                  3.0
# 81                    Other        5.0                  2.0
# 83                Marketing        2.0                  5.0
# 85                    Other        2.0                  1.0
# 88                    Other        2.0                  1.0
# 89                    Other        2.0                  1.0
# 92               Purchasing        2.0                  5.0
# 97                    Sales        2.0                  3.0
# 98                    Other        5.0                  6.0
# 99                    Other        2.0                  1.0
# 101                   Sales        2.0                  3.0
# 102                   Other        4.0                  5.0
# 103  Information Technology        4.0                  5.0
# 104      Project Management        2.0                  4.0
# 105              Consulting        2.0                  5.0
# 106          Administrative        4.0                  2.0
# 107                   Other        2.0                  1.0
# 108                   Other        5.0                  6.0
#
#        predicted_department
# 5    Information Technology
# 8                     Sales
# 9            Administrative
# 10                    Other
# 11                    Other
# 14                    Other
# 23               Purchasing
# 29                    Other
# 33                      NaN
# 42          Human Resources
# 44                    Other
# 45       Project Management
# 46                    Other
# 47                    Other
# 55                    Sales
# 56     Business Development
# 64                    Other
# 67                    Other
# 69                    Other
# 70         Customer Support
# 72     Business Development
# 76                Marketing
# 79       Project Management
# 81                    Other
# 83                Marketing
# 85                    Other
# 88          Human Resources
# 89                    Other
# 92               Purchasing
# 97                    Sales
# 98                    Other
# 99                    Other
# 101                   Sales
# 102          Administrative
# 103  Information Technology
# 104      Project Management
# 105              Consulting
# 106          Administrative
# 107          Administrative
# 108                   Other

# %%
# now do the same for department
correct_department = results_df[results_df["department"] == results_df["predicted_department"]]
accuracy_department = len(correct_department) / len(results_df) * 100
print(f"Department Prediction Accuracy: {accuracy_department:.2f}%")
# Out:
# Department Prediction Accuracy: 79.61%

# %%
# show me where department != predicted_department
incorrect_department = results_df[results_df["department"] != results_df["predicted_department"]]
incorrect_department.head(10)
# Out:
#     row_id  cv_id                                       organization  \
# 7        7      3                              Grupo Viajes Kontiki.
# 10      10      4                  Himmelstalunds Utbildningscentrum
# 11      11      5                       FSD Fahrzeugsystemdaten GmbH
# 21      21     13                         Landeshauptstadt Wiesbaden
# 33      33     27                                       Stork Lijmen
# 43      43     39                                Quest ontheFRONTIER
# 57      57     55                                          myclimate
# 75      75     72                         Austria Wirtschaftsservice
# 80      80     77                                Körber Technologies
# 84      84     80  Bureau Maaiveld, het breed inzetbare bureau vo...
#
#                                              position              department  \
# 7                      Director expansión de negocio.    Business Development
# 10                           APL-ansvarig, samordning          Administrative
# 11                              Kaufmännischer Leiter                   Sales
# 21                     Leistungssachbearbeiter SGB II                   Other
# 33                                                CEO                   Other
# 43                         Human Resources Consultant              Consulting
# 57                            Projektleiterin Bildung                   Other
# 75  Head of aws Preseed and Seedfinancing - Innova...                   Other
# 80  Project Engineer Process Technology - Future F...  Information Technology
# 84                                           Eigenaar                   Other
#
#     seniority  predicted_seniority  predicted_department
# 7         6.0                  6.0                 Other
# 10        4.0                  2.0                 Other
# 11        4.0                  5.0                 Other
# 21        2.0                  2.0        Administrative
# 33        5.0                  NaN                   NaN
# 43        2.0                  2.0       Human Resources
# 57        4.0                  4.0    Project Management
# 75        4.0                  4.0  Business Development
# 80        2.0                  2.0    Project Management
# 84        5.0                  5.0  Business Development
